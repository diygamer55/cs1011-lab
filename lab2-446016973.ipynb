# %% [markdown]
#  # Lab 2:
#  **Name:** *Albraa Hassan*
#
#  **ID:** *446016973*

# %% [markdown]
# ### Part 1: Alphabetical Order (10%)

# %% [markdown]
# Write a program that takes in three lowercase characters and outputs the characters in alphabetical order. The program must read and output the characters as a list.

# %% [markdown]
# #### Hint: Ordering three characters takes six permutations.

# %% [markdown]
# Ex: If the input is:
#
# first character: b
#
# second character: c
#
# third character: a
#
# the output is:
#
# ('a', 'b', 'c')

# %%
def alphabetical_order(first,second,third):
    #ToDo
      if first > second:
       exchange = first
       first = second
       second = exchange
      if second > third:
       exchange = second
       second = third
       third = exchange
      if first > second:
       exchange = first
       first = second
       second = exchange
      return (first, second, third)
      pass

# Read three characters
first = input('first characters:').strip()
second = input('second characters:').strip()
third = input('third characters:').strip()


print(f'characters: {first,second,third}')
print(f'The characters in alphabetical order: {alphabetical_order(first,second,third)}')
# Out:
# first characters:m
# second characters:i
# third characters:t
# characters: ('m', 'i', 't')
# The characters in alphabetical order: ('i', 'm', 't')

# %% [markdown]
# ### Part 2: Count odd numbers (10%)

# %% [markdown]
# Write a program that takes in four positive integers and outputs the number of odd numbers.

# %% [markdown]
# Ex: If the input is:
#
# first num: 1
#
# second num: 2
#
# third num: 3
#
# fourth num: 4
#
#
# the output is: 2

# %% [markdown]
# Ex: If the input is:
#
# first num: 19
#
# second num: 19
#
# third num: 19
#
# fourth num: 10
#
#
# the output is: 4

# %%
def count_odd(first,second,third,fourth):
    #ToDo
    count = 0
    if first % 2 != 0:
        count += 1
    if second % 2 != 0:
        count += 1
    if third % 2 != 0:
            count += 1
    if fourth % 2 != 0:
            count += 1
    return count
    pass


first = int(input('first number:'))
second = int(input('second number:'))
third = int(input('third number:'))
fourth = int(input('fourth number:'))

print(f'\nNumber of odd is {count_odd(first,second,third,fourth)}')
# Out:
# first number:4
# second number:8
# third number:9
# fourth number:6
#
# Number of odd is 1

# %% [markdown]
# #### Optional Step:
#
# - Download the python file [l2grader](https://github.com/mknifiai/cs1011-lab/blob/main/l2grader.py) to test your code.
#
# - Place the file in your current working directory. Then run the following code cell

# %%
# %run -i 'l2grader.py'

# %% [markdown]
# ## Check in

# %% [markdown]
# #### - <font color='red'>Rename this file as follows: lab3-YOUR_UQU_ID.ipynb <font>

# %% [markdown]
# #### - <font color='red'>Upload your notebook file to Blackboard<font>
